# %%
def glorp(n):
    g = list(format(n, "08b"))
    for i in range(len(g)):
        t = g[i]
        g[i] = g[(i * 332 + 6) % 8]
        g[(i * 332 + 6) % 8] = t
    return int(''.join(g), 2)

lookup = [glorp(i) for i in range(256)]
inv_loopup = [glorp(i) for i in range(256)]
lookup
# Out:
# [0,
#  32,
#  128,
#  160,
#  1,
#  33,
#  129,
#  161,
#  2,
#  34,
#  130,
#  162,
#  3,
#  35,
#  131,
#  163,
#  4,
#  36,
#  132,
#  164,
#  5,
#  37,
#  133,
#  165,
#  6,
#  38,
#  134,
#  166,
#  7,
#  39,
#  135,
#  167,
#  64,
#  96,
#  192,
#  224,
#  65,
#  97,
#  193,
#  225,
#  66,
#  98,
#  194,
#  226,
#  67,
#  99,
#  195,
#  227,
#  68,
#  100,
#  196,
#  228,
#  69,
#  101,
#  197,
#  229,
#  70,
#  102,
#  198,
#  230,
#  71,
#  103,
#  199,
#  231,
#  8,
#  40,
#  136,
#  168,
#  9,
#  41,
#  137,
#  169,
#  10,
#  42,
#  138,
#  170,
#  11,
#  43,
#  139,
#  171,
#  12,
#  44,
#  140,
#  172,
#  13,
#  45,
#  141,
#  173,
#  14,
#  46,
#  142,
#  174,
#  15,
#  47,
#  143,
#  175,
#  72,
#  104,
#  200,
#  232,
#  73,
#  105,
#  201,
#  233,
#  74,
#  106,
#  202,
#  234,
#  75,
#  107,
#  203,
#  235,
#  76,
#  108,
#  204,
#  236,
#  77,
#  109,
#  205,
#  237,
#  78,
#  110,
#  206,
#  238,
#  79,
#  111,
#  207,
#  239,
#  16,
#  48,
#  144,
#  176,
#  17,
# ...

# %%
img = df.to_numpy().transpose()
img
# Out:
# array([[254., 254., 254., ..., 252., 252., 252.],
#        [255., 255., 255., ..., 247., 247., 247.],
#        [246., 246., 246., ..., 254., 254., 254.],
#        ...,
#        [  8.,   8.,   8., ...,   0.,   0.,   0.],
#        [  1.,   1.,   1., ...,  10.,  10.,  10.],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan]])

# %%
plt.figure(figsize=(18, 30), dpi=80)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)

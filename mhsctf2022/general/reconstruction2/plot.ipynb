# %%
import re
with open("e0207a466c45d47d296a0386e287b575.txt",'r') as f:
    s = f.read()
#s = s.replace("\n","")
s = s.replace("\nm", "\n[[")
s = s.replace("z\n", "]],\n\n\n")
s = s.replace("l", "],\n[")
s = s.replace("q", "],[")
s = s.replace(" ", ",")
s = s.replace(",.*",",")
#s = re.sub(r',\[.*,.*,.*,.*\],\[.*,.*,.*,.*[0-9]\]', '', s)
print(s)
# Out:
# m10.845062,371.57135],
# [0,-22.484375],[0,-1.78125,1.203125,-2.984375],[1.21875,-1.21875,2.984375,-1.21875],
# [7.34375,0],
# [0,2.84375],
# [-7.34375,0],[-0.5625,0,-0.96875,0.40625],[-0.390625,0.390625,-0.390625,0.953125],
# [0,2.390625],
# [8.703125,0],
# [0,2.828125],
# [-8.703125,0],
# [0,17.265625],
# [-2.828125,0]],
#
#
# [[29.106415,371.57135],[-1.734375,0,-2.96875,-1.21875],[-1.234375,-1.234375,-1.234375,-2.96875],
# [0,-22.5],
# [2.84375,0],
# [0,22.5],[0,0.546875,0.390625,0.953125],[0.40625,0.390625,0.96875,0.390625],
# [3.390625,0],
# [0,2.84375],
# [-3.390625,0]],
#
#
# [[39.572617,371.57135],[-1.734375,0,-2.96875,-1.21875],[-1.234375,-1.234375,-1.234375,-2.96875],
# [0,-7.28125],
# [17.609375,0],
# [0,-4.4375],[0,-0.5625,-0.40625,-0.953125],[-0.390625,-0.40625,-0.9375,-0.40625],
# [-16.265625,0],
# [0,-2.828125],
# [16.265625,0],[1.765625,0,2.984375,1.234375],[1.234375,1.21875,1.234375,2.953125],
# [0,15.90625],
# [-16.28125,0zm0,-2.84375],
# [13.40625,0],
# ...

# %%
data = [[[10.845062,371.57135],
[0,-22.484375],
[7.34375,0],
[0,2.84375],
[-7.34375,0],
[0,2.390625],
[8.703125,0],
[0,2.828125],
[-8.703125,0],
[0,17.265625],
[-2.828125,0]],
[[29.106415,371.57135],
[0,-22.5],
[2.84375,0],
[0,22.5],
[3.390625,0],
[0,2.84375],
[-3.390625,0]],
[[39.572617,371.57135],
[0,-7.28125],
[17.609375,0],
[0,-4.4375],
[-16.265625,0],
[0,-2.828125],
[16.265625,0],
[0,15.90625],
[-16.28125,0]],
[[0,-2.84375],
[13.40625,0],
[0,-5.78125],
[-14.765625,0],
[0,4.4375]],
[[62.749084,379.50885],
[0,-2.875],
[12.546875,0],
[0,-3.703125],
[-13.421875,0],
[0,-11.71875],
[12.0625,0],
[0,19.609375],
[-12.546875,0]],
[[0.484375,-10.78125],
[12.0625,0],
[0,-11.71875],
[-12.0625,0],
[0,11.71875]],
[[87.91933,371.57135],
[0,-5.65625],
[-1.625,-1.0],
[0,-3.328125],
[1.625,-0.875],
[0,-5.671875],
[1.0,0],
[0,2.875],
[-1.0,0],
[0,5.921875],
[-2.90625,2.328125],
[2.90625,2.390625],
[0,5.890625],
[1.0,0],
[0,2.84375],
[-1.0,0]],
[[97.16937,371.57135],
[0,-0.28125],
[2.84375,0],
[0,0.28125],
[12.0625,0],
[0,-3.09375],
[-12.0625,0],
[0,-3.078125],
[12.0625,0],
[0,0.28125],
[-2.875,0],
[0,-0.28125],
[-12.0625,0],
[0,3.078125],
[12.0625,0],
[0,3.09375],
[-12.0625,0]],
[[126.89671,371.57135],
[-11.078125,-20.09375],
[3.328125,0],
[9.421875,17.328125],
[9.421875,-17.328125],
[3.328125,0],
[-11.125,20.09375],
[-3.296875,0]],
[[147.58768,379.50885],
[0,-2.875],
[12.546875,0],
[0,-3.703125],
[-13.421875,0],
[0,-11.71875],
[12.0625,0],
[0,19.609375],
[-12.546875,0]],
[[0.484375,-10.78125],
[12.0625,0],
[0,-11.71875],
[-12.0625,0],
[0,11.71875]],
[[168.00792,374.4151],
[0,-2.84375],
[25.21875,0],
[0,2.84375],
[-25.21875,0]],
[[196.70332,371.57135],
[0,-26.6875],
[2.84375,0],
[0,6.59375],
[13.4375,0],
[0,11.71875],
[-16.28125,0]],
[[4.21875,-2.84375],
[12.0625,0],
[0,-11.71875],
[-12.0625,0],
[0,11.71875]],
[[235.55344,371.57135],
[0,-6.453125],
[-17.40625,0],
[0,-3.1875],
[17.0625,-15.34375],
[3.1875,0],
[0,15.703125],
[3.875,0],
[0,2.828125],
[-3.875,0],
[0,6.453125],
[-2.84375,0]],
[[-13.765625,-9.28125],
[13.765625,0],
[0,-11.859375],
[-13.765625,11.859375]],
[[249.19627,371.57135],
[0,-11.71875],
[16.23436,0],
[0,2.828125],
[-16.23436,0],
[0,11.71875],
[16.29686,0],
[0,2.84375],
[-16.29686,0]],
[[269.20425,371.57135],
[0,-26.6875],
[2.84375,0],
[0,15.21875],
[5.546875,0],
[7.890625,-8.625],
[3.75,0],
[0,0.03125],
[-9.125,10.015625],
[9.09375,10.015625],
[0,0.03125],
[-3.71875,0],
[-7.890625,-8.625],
[-5.546875,0],
[0,8.625],
[-2.84375,0]],
[[294.8422,379.50885],
[0,-2.875],
[12.546875,0],
[0,-3.703125],
[-13.421875,0],
[0,-11.71875],
[12.0625,0],
[0,19.609375],
[-12.546875,0]],
[[0.484375,-10.78125],
[12.0625,0],
[0,-11.71875],
[-12.0625,0],
[0,11.71875]],
[[315.1843,371.57135],
[0,-15.90625],
[11.296875,0],
[0,2.828125],
[-11.296875,0],
[0,15.90625],
[-2.84375,0]],
[[337.3033,371.57135],
[0,-16.53125],
[16.8125,0],
[0,16.53125],
[-16.8125,0]],
[[-1.015625,-2.84375],
[17.828125,0],
[0,-14.453125],
[-19.171875,15.796875]],
[[-0.34375,-3.421875],
[19.140625,-15.8125],
[-17.78125,0],
[0,14.453125]],
[[366.066,371.57135],
[0,-15.90625],
[2.828125,0],
[0,15.90625],
[12.0625,0],
[0,-15.90625],
[2.828125,0],
[0,15.90625],
[-12.0625,0]],
[[385.99588,371.57135],
[0,-20.09375],
[16.28125,0],
[0,15.90625],
[-2.84375,0],
[0,-15.90625],
[-12.0625,0],
[0,15.90625],
[-2.84375,0]],
[[413.27292,371.57135],
[0,-11.71875],
[13.40625,0],
[0,-6.59375],
[2.84375,0],
[0,26.6875],
[-16.25,0]],
[[0,-2.84375],
[12.046875,0],
[0,-11.71875],
[-12.046875,0],
[0,11.71875]],
[[437.52927,371.57135],
[0,-1.015625],
[2.84375,0],
[0,1.015625],
[16.8125,0],
[0,-5.890625],
[-21.015625,0],
[0,-13.546875],
[25.203125,0],
[0,2.875],
[-21.0,0],
[0,5.09375],
[16.8125,0],
[0,5.890625],
[-16.8125,0]],
[[461.9971,374.4151],
[0,-2.84375],
[25.21875,0],
[0,2.84375],
[-25.21875,0]],
[[506.42688,371.57135],
[0,-6.453125],
[-17.40625,0],
[0,-3.1875],
[17.0625,-15.34375],
[3.1875,0],
[0,15.703125],
[3.875,0],
[0,2.828125],
[-3.875,0],
[0,6.453125],
[-2.84375,0]],
[[-13.765625,-9.28125],
[13.765625,0],
[0,-11.859375],
[-13.765625,11.859375]],
[[515.9135,371.57135],
[0,-15.90625],
[11.296875,0],
[0,2.828125],
[-11.296875,0],
[0,15.90625],
[-2.84375,0]],
[[537.92316,371.57135],
[0,-0.5625],
[2.875,0],
[0,0.5625],
[16.8125,0],
[0,-5.796875],
[-16.25,0],
[0,-2.84375],
[15.140625,0],
[0,-5.234375],
[-15.703125,0],
[0,0.90625],
[-2.875,0],
[0,-0.90625],
[15.703125,0],
[0,5.234375],
[0,5.796875],
[-16.8125,0]],
[[562.36176,374.4151],
[0,-2.84375],
[25.21875,0],
[0,2.84375],
[-25.21875,0]],
[[595.13525,371.57135],
[0,-11.71875],
[16.234375,0],
[0,2.828125],
[-16.234375,0],
[0,11.71875],
[16.296875,0],
[0,2.84375],
[-16.296875,0]],
[[619.4401,371.57135],
[0,-16.53125],
[16.8125,0],
[0,16.53125],
[-16.8125,0]],
[[-1.015625,-2.84375],
[17.828125,0],
[0,-14.453125],
[-19.171875,15.796875]],
[[-0.34375,-3.421875],
[19.140625,-15.8125],
[-17.78125,0],
[0,14.453125]],
[[648.34344,371.57135],
[0,-16.53125],
[16.8125,0],
[0,16.53125],
[-16.8125,0]],
[[-1.015625,-2.84375],
[17.828125,0],
[0,-14.453125],
[-19.171875,15.796875]],
[[-0.34375,-3.421875],
[19.140625,-15.8125],
[-17.78125,0],
[0,14.453125]],
[[678.66864,371.57135],
[0,-21.765625],
[-3.84375,4.609375],
[-3.71875,0],
[6.546875,-7.796875],
[3.890625,0],
[0,24.953125],
[-2.875,0]],
[[686.3911,371.57135],
[0,-2.84375],
[1.0,0],
[0,-5.859375],
[2.90625,-2.390625],
[-2.90625,-2.296875],
[0,-5.984375],
[-1.0,0],
[0,-2.875],
[1.0,0],
[0,5.671875],
[1.59375,0.9375],
[0,3.296875],
[-1.59375,1.0],
[0,5.625],
[-1.0,0]],]
for d in data:
    print(d[0])
# Out:
# [10.845062, 371.57135]
# [29.106415, 371.57135]
# [39.572617, 371.57135]
# [0, -2.84375]
# [62.749084, 379.50885]
# [0.484375, -10.78125]
# [87.91933, 371.57135]
# [97.16937, 371.57135]
# [126.89671, 371.57135]
# [147.58768, 379.50885]
# [0.484375, -10.78125]
# [168.00792, 374.4151]
# [196.70332, 371.57135]
# [4.21875, -2.84375]
# [235.55344, 371.57135]
# [-13.765625, -9.28125]
# [249.19627, 371.57135]
# [269.20425, 371.57135]
# [294.8422, 379.50885]
# [0.484375, -10.78125]
# [315.1843, 371.57135]
# [337.3033, 371.57135]
# [-1.015625, -2.84375]
# [-0.34375, -3.421875]
# [366.066, 371.57135]
# [385.99588, 371.57135]
# [413.27292, 371.57135]
# [0, -2.84375]
# [437.52927, 371.57135]
# [461.9971, 374.4151]
# [506.42688, 371.57135]
# [-13.765625, -9.28125]
# [515.9135, 371.57135]
# [537.92316, 371.57135]
# [562.36176, 374.4151]
# [595.13525, 371.57135]
# [619.4401, 371.57135]
# [-1.015625, -2.84375]
# [-0.34375, -3.421875]
# [648.34344, 371.57135]
# [-1.015625, -2.84375]
# ...

# %%
import re
import numpy as np
import matplotlib.pyplot as plt

def read_x_y(s):
    tmp = s.split('l')[0].split('q')[0].split('z')[0]
    x = float(tmp.split(" ")[0])
    y = float(tmp.split(" ")[1])
    return x,y,s[len(tmp):]

with open("e0207a466c45d47d296a0386e287b575.txt",'r') as f:
    ls = f.readlines()
    for l in ls:
        print(l)
        x,y,l = read_x_y(l[1:-1])
        print(x,y)
        while True:
            #print("l=",l)
            if l == "" or len(l) == 1:
                print()
                break
            elif l[0] == 'q':
                a = l.find('l')
                b = l.find('m')
                c = l.find('z')
                l = l[np.min([a if a > 0 else 999999,b if b > 0 else 999999,c if c > 0 else 999999]):]
            elif l[0] == 'l':
                tx ,ty, l = read_x_y(l[1:])
                x = x + tx
                y = y + ty
                print(x,y)
                plt.plot([x-tx,x],[-y+ty,-y],"-",color="k")
                plt.scatter(x,-y)
            elif l[0] == 'z' and l[1] == 'm':
                tx ,ty, l = read_x_y(l[2:])
                x = x+ tx
                y = y + ty
                print(x,y)
                plt.scatter(x,-y)
                
        plt.show()
# Out:
# m10.845062 371.57135l0 -22.484375q0 -1.78125 1.203125 -2.984375q1.21875 -1.21875 2.984375 -1.21875l7.34375 0l0 2.84375l-7.34375 0q-0.5625 0 -0.96875 0.40625q-0.390625 0.390625 -0.390625 0.953125l0 2.390625l8.703125 0l0 2.828125l-8.703125 0l0 17.265625l-2.828125 0z
#
# 10.845062 371.57135
# 10.845062 349.086975
# 18.188812 349.086975
# 18.188812 351.930725
# 10.845061999999999 351.930725
# 10.845061999999999 354.32135
# 19.548187 354.32135
# 19.548187 357.149475
# 10.845061999999999 357.149475
# 10.845061999999999 374.4151
# 8.016936999999999 374.4151
# m29.106415 371.57135q-1.734375 0 -2.96875 -1.21875q-1.234375 -1.234375 -1.234375 -2.96875l0 -22.5l2.84375 0l0 22.5q0 0.546875 0.390625 0.953125q0.40625 0.390625 0.96875 0.390625l3.390625 0l0 2.84375l-3.390625 0z
#
# 29.106415 371.57135
# 29.106415 349.07135
# 31.950165 349.07135
# 31.950165 371.57135
# 35.34079 371.57135
# 35.34079 374.4151
# 31.950165 374.4151
# ...

# %%
plt.figure(figsize=(18, 30), dpi=80)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-27fad85a08c9> in <module>
# ----> 1 plt.figure(figsize=(18, 30), dpi=80)
#       2 plt.imshow(img, cmap='gray', vmin=0, vmax=255)
#
# NameError: name 'plt' is not defined
